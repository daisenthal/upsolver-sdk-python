# %%
import os
import sys
from pathlib import Path
module_path = str(Path.cwd().parent.parent)
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from upsolverapi.src.client import UpsolverApi

# %%
user = ""
password = ""
api = UpsolverApi(env='local', user_email=user, user_password=password)

# %%
api.execute_command("create table local.efrat.tbl")
# Out:
# {'status': 'Success',
#  'kind': 'upsolver_query_response',
#  'affectedEntities': [{'uri': '/managed-tables/79744919-06c5-428b-b35d-15df9ec32ed0',
#    'action': 'Create'}],
#  'message': 'Table created successfully',
#  'executedStatementRange': {'start': {'line': 1, 'column': 1},
#   'end': {'line': 1, 'column': 28}}}

# %%
tables = api.query_to_df("select * from information_schema.tables")
tables
# Out:
#   catalog comment        created_at                  created_by  \
# 0   local          2023-02-01 02:14  efrat (efrat@upsolver.com)
# 1   local          2023-02-01 02:53  efrat (efrat@upsolver.com)
# 2   local          2023-02-01 05:48  efrat (efrat@upsolver.com)
#
#                                      id                 modified_by name  \
# 0  f7d9e806-de18-488a-949b-c22c94c15822  efrat (efrat@upsolver.com)   t1
# 1  10781fa5-a5fe-46a2-a3e5-e8b4493db649  efrat (efrat@upsolver.com)   t2
# 2  79744919-06c5-428b-b35d-15df9ec32ed0  efrat (efrat@upsolver.com)  tbl
#
#   schema
# 0  efrat
# 1  efrat
# 2  efrat

# %%
data = api.query_to_df("select * from local.efrat.t1 limit 1000")
data.head(10)
# Out:
#                                                  app   at  \
# 0  {"bundle":"314716233","cat":["IAB24","IAB3","s...  2.0
# 1  {"bundle":"642064350","cat":["IAB1","IAB1-6","...  2.0
# 2  {"bundle":"448999087","cat":["IAB1","IAB14","e...  2.0
# 3  {"bundle":"429610587","cat":["IAB1","IAB9","IA...  2.0
# 4  {"bundle":"804379658","cat":["IAB1","IAB9","IA...  2.0
# 5  {"bundle":"292987597","cat":["IAB14","IAB7","h...  2.0
# 6  {"bundle":"448999087","cat":["IAB1","IAB14","e...  2.0
# 7  {"bundle":"285688934","cat":["IAB20","IAB24","...  2.0
# 8  {"bundle":"642064350","cat":["IAB1","IAB1-6","...  2.0
# 9  {"bundle":"372648912","cat":["IAB24","social_n...  2.0
#
#                                                 badv  \
# 0  ["chaton","gifchat","infinite","kakao","messag...
# 1             ["fabuloussites.com","mymixtapez.com"]
# 2  ["att.ecustomersupport.com","attbestdeals.com"...
# 3                                               None
# 4                       ["wordswithfriends","zynga"]
# 5  ["applovin","benaughty","gameofwar.com","gameo...
# 6  ["att.ecustomersupport.com","attbestdeals.com"...
# 7  ["avazutracking","ebuddy","http://seth.avazutr...
# 8             ["fabuloussites.com","mymixtapez.com"]
# 9  ["badoo","chatmeup","diy","diy.com","fling","h...
#
#                                                 bcat  \
# 0  ["IAB25","IAB26","IAB7-39","IAB8-18","IAB8-5",...
# 1                         ["IAB25","IAB26","IAB3-7"]
# 2                         ["IAB25","IAB26","IAB3-7"]
# 3  ["IAB25","IAB26","IAB7-39","IAB8-18","IAB8-5",...
# 4  ["IAB25","IAB25-2","IAB26","IAB7-39","IAB9-9",...
# 5  ["IAB25","IAB26","IAB7-39","IAB8-18","IAB8-5",...
# 6                         ["IAB25","IAB26","IAB3-7"]
# 7  ["IAB25","IAB26","IAB7-39","IAB8-18","IAB8-5",...
# 8                         ["IAB25","IAB26","IAB3-7"]
# 9  ["IAB25","IAB25-2","IAB25-3","IAB25-4","IAB25-...
#
#                                               device  \
# 0  {"connectiontype":2,"devicetype":4,"dnt":0,"h"...
# 1  {"connectiontype":2,"devicetype":4,"dnt":0,"h"...
# 2  {"connectiontype":2,"devicetype":4,"dnt":0,"h"...
# 3  {"connectiontype":2,"devicetype":4,"dnt":0,"h"...
# 4  {"connectiontype":3,"devicetype":4,"dnt":0,"h"...
# 5  {"connectiontype":2,"devicetype":4,"dnt":0,"h"...
# 6  {"connectiontype":3,"devicetype":4,"dnt":0,"h"...
# 7  {"connectiontype":2,"devicetype":4,"dnt":0,"h"...
# 8  {"connectiontype":3,"devicetype":4,"dnt":0,"h"...
# 9  {"connectiontype":3,"devicetype":4,"dnt":0,"h"...
#
#                                                  ext                id  \
# 0  {"envisionx":{"imp_price_available":true,"ssp"...  5757C5C5204A4941
# 1  {"envisionx":{"imp_price_available":true,"ssp"...  C9014FED9BEC26BB
# 2  {"envisionx":{"imp_price_available":true,"ssp"...  FD9BA6311799D684
# 3  {"envisionx":{"imp_price_available":true,"ssp"...  E4FFD519AD661E64
# 4  {"envisionx":{"imp_price_available":true,"ssp"...  70B335DC4BE0B22F
# 5  {"envisionx":{"imp_price_available":true,"ssp"...  A06A7564B93D6F7A
# 6  {"envisionx":{"imp_price_available":true,"ssp"...  4CF88975BD7ACD34
# 7  {"envisionx":{"imp_price_available":true,"ssp"...  9F21C34A409E117F
# 8  {"envisionx":{"imp_price_available":true,"ssp"...  00791AA23695F35A
# 9  {"envisionx":{"imp_price_available":true,"ssp"...  A5A9F416CFC5C122
#
#                                                  imp  \
# 0  [{"bidfloor":2.08,"displaymanager":"mopub","di...
# 1  [{"bidfloor":0.19,"displaymanager":"mopub","di...
# 2  [{"bidfloor":3.38,"displaymanager":"mopub","di...
# 3  [{"bidfloor":2.08,"displaymanager":"mopub","di...
# 4  [{"bidfloor":2.44,"displaymanager":"mopub","di...
# 5  [{"bidfloor":0.08,"displaymanager":"mopub","di...
# 6  [{"bidfloor":0.49,"displaymanager":"mopub","di...
# 7  [{"bidfloor":1.09,"displaymanager":"mopub","di...
# 8  [{"bidfloor":0.19,"displaymanager":"mopub","di...
# 9  [{"bidfloor":0.09,"displaymanager":"mopub","di...
#
#                                                 user
# 0  {"keywords":"m_age:31,m_app_version:6.22.0,m_p...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {"keywords":"z_sdkversion:4.7.1,z_impression_i...
# 5                                               None
# 6                                               None
# 7  {"keywords":"app_version:8.7.2,country:us,mobi...
# 8                                               None
# 9  {"keywords":"ETHNICITY:BLACK,EDUCATION:NONE,RE...
